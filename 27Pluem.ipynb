# %% [markdown]
# <a href="https://colab.research.google.com/github/28783-Patsakorn/27-coding68/blob/main/27Pluem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
อายุ=int(input("กรุณาระบุปีเกิด(พ.ศ) : "))
อายุ=(2568-อายุ)
if อายุ>=18:
  print("ไปเลือกตั้งได้")
else:
  print("ไม่สามารถเลือกตั้งได้")
# Out:
# กรุณาระบุปีเกิด(พ.ศ) : 2449
# ไปเลือกตั้งได้
